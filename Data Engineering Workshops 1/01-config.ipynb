# %%
base_dir_data = spark.sql("describe external location `data-zone`").select("url").collect()[0][0]

base_dir_data = spark.sql("describe external location `data-zone`").select("url").collect()[0][0]
